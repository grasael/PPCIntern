# %% [markdown]
# <a href="https://colab.research.google.com/github/grasael/PPCIntern/blob/main/New_Real_Estate_Allegheny_County.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Zillow Property Search
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1afLUQVYLIhv0vDB-GNuYgxfZrJhTzSM5?usp=sharing)
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
# Reference: https://www.youtube.com/watch?v=bcZe01LhdFc&t=132s&ab_channel=TechinRealEstate

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %%
pip install usps-api
# Out:
# Collecting usps-api
#   Downloading usps-api-0.5.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from usps-api) (2.27.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from usps-api) (4.9.2)
# Collecting xmltodict (from usps-api)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->usps-api) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->usps-api) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->usps-api) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->usps-api) (3.4)
# Building wheels for collected packages: usps-api
#   Building wheel for usps-api (setup.py) ... done
#   Created wheel for usps-api: filename=usps_api-0.5-py3-none-any.whl size=5893 sha256=fc71a6a48544fa8c2b55e36ccded53c4d744962f724d0f81c1367bc62d244476
#   Stored in directory: /root/.cache/pip/wheels/bb/99/fd/b92ad0410977916aa50fe09b8d5a0cc8a19be86445dbe07ba0
# Successfully built usps-api
# Installing collected packages: xmltodict, usps-api
# Successfully installed usps-api-0.5 xmltodict-0.13.0

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import output, drive, files # specific to Google Colab
import pandas as pd
import numpy as np
import plotly.express as px
import requests
import warnings
import re

# settings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %%
def get_listings(api_key, listing_url):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"

    querystring = {
        "api_key": api_key,
        "url":listing_url
    }

    return requests.request("GET", url, params=querystring)

def get_property_detail(api_key, zpid):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/property"

    querystring = {
        "api_key": api_key,
        "zpid":zpid
    }

    return requests.request("GET", url, params=querystring)

def get_zpid(api_key, street, city, state, zip_code=None):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/zpidByAddress"

    querystring = {
        "api_key": api_key,
        "street": street,
        "city": city,
        "state": state,
        "zip_code":zip_code
    }

    return requests.request("GET", url, params=querystring)

def split_address(full_address):
    abbreviations = {
        'Ave': 'Avenue',
        'Blvd': 'Boulevard',
        'Cir': 'Circle',
        'Ct': 'Court',
        'Dr': 'Drive',
        'Ln': 'Lane',
        'Pl': 'Place',
        'Rd': 'Road',
        'St': 'Street',
        'Sq': 'Square',
        'Ter': 'Terrace',
        'Trl': 'Trail',
        'Pkwy': 'Parkway',
        'Hwy': 'Highway'
    }

    address1 = ""
    address2 = ""
    for abbreviation in abbreviations:
        pattern = r'(?<=\b' + abbreviation + r'\b)(.*)'
        match = re.search(pattern, full_address)
        if match:
            address1 = full_address[:match.start()].strip()
            address2 = match.group(1).strip()
            break

    return address1, address2

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
# # read in api key file
# df_api_keys = pd.read_csv(file_dir + "api_keys.csv")

# # get keys
api_key = "6482e290-cfb0-4c53-aad1-1d82cad30381"

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### <font color="green">1. Retrieving Addresses </font>

# %%
# zillow search url
listing_url = "https://www.zillow.com/pittsburgh-pa-15213/sold/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22usersSearchTerm%22%3A%2215213%22%2C%22mapBounds%22%3A%7B%22west%22%3A-80.01516565124513%2C%22east%22%3A-79.92418512145997%2C%22south%22%3A40.412972189053114%2C%22north%22%3A40.46967273849898%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A63944%2C%22regionType%22%3A7%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%2C%22fsbo%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22rs%22%3A%7B%22value%22%3Atrue%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22schu%22%3A%7B%22value%22%3Afalse%7D%2C%22sche%22%3A%7B%22value%22%3Afalse%7D%2C%22schm%22%3A%7B%22value%22%3Afalse%7D%2C%22schh%22%3A%7B%22value%22%3Afalse%7D%2C%22schp%22%3A%7B%22value%22%3Afalse%7D%2C%22schr%22%3A%7B%22value%22%3Afalse%7D%2C%22schc%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A13%7D"
# get listings
listing_response = get_listings(api_key, listing_url)

# %%
# view all keys
listing_response.json().keys()
# Out:
# dict_keys(['is_success', 'data', 'message'])

# %%
# check if request is successful
listing_response.json()["is_success"]
# Out:
# True

# %%
# view count of properies returned in request
num_of_properties = listing_response.json()["data"]["categoryTotals"]["cat1"]["totalResultCount"]
print("Count of properties:", num_of_properties)
# Out:
# Count of properties: 824

# %%
# view all listings
df_listings = pd.json_normalize(listing_response.json()["data"]["cat1"]["searchResults"]["mapResults"])
print("Number of rows:", len(df_listings))
print("Number of columns:", len(df_listings.columns))
df_listings
# Out:
# Number of rows: 460
# Number of columns: 86
#           zpid     price priceLabel  beds  baths    area statusType  \
# 0     11407883    $1.00M     $1.00M   6.0    4.0  5255.0       SOLD
# 1     11407340  $675,000      $675K   4.0    5.0  2085.0       SOLD
# 2     11419828  $290,000      $290K   3.0    2.0  1100.0       SOLD
# 3     11420187  $170,000      $170K   4.0    2.0  2152.0       SOLD
# 4          NaN                  NaN   NaN    NaN     NaN       SOLD
# ..         ...       ...        ...   ...    ...     ...        ...
# 455   11420319  $335,000      $335K   6.0    3.0  1960.0       SOLD
# 456   11528845  $175,000      $175K   1.0    1.0  1090.0       SOLD
# 457   11528950  $390,000      $390K   4.0    3.0  1688.0       SOLD
# 458  164658134  $390,000      $390K   3.0    2.5     NaN       SOLD
# 459   11413689  $245,000      $245K   5.0    2.0  1968.0       SOLD
#
#     statusText  isFavorite isUserClaimingOwner isUserConfirmedClaim  \
# 0         Sold       False               False                False
# 1         Sold       False               False                False
# 2         Sold       False               False                False
# 3         Sold       False               False                False
# 4     For Rent       False                 NaN                  NaN
# ..         ...         ...                 ...                  ...
# 455       Sold       False               False                False
# 456       Sold       False               False                False
# 457       Sold       False               False                False
# 458       Sold       False               False                False
# 459       Sold       False               False                False
#
#                                                 imgSrc hasImage visited  \
# 0    https://photos.zillowstatic.com/fp/c61dc6f88e0...     True   False
# 1    https://photos.zillowstatic.com/fp/ad6fe457f55...     True   False
# 2    https://photos.zillowstatic.com/fp/bb8ce132462...     True   False
# 3    https://photos.zillowstatic.com/fp/60c4331a573...     True   False
# 4    https://photos.zillowstatic.com/fp/532db3efc7d...     True     NaN
# ..                                                 ...      ...     ...
# 455  https://photos.zillowstatic.com/fp/77ac9fb2878...     True   False
# 456  https://photos.zillowstatic.com/fp/c3219e76f98...     True   False
# 457  https://photos.zillowstatic.com/fp/7fe1f46b644...     True   False
# 458  https://photos.zillowstatic.com/fp/bbe092b816b...     True   False
# 459  https://photos.zillowstatic.com/fp/3b96991dd06...     True   False
#
#     listingType shouldShowZestimateAsPrice  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                      NaN
# ..          ...                        ...
# 455                                  False
# 456                                  False
# 457                                  False
# 458                                  False
# 459                                  False
#
#                                              detailUrl         pgapt  \
# 0    /homedetails/4305-Bigelow-Blvd-Pittsburgh-PA-1...  RecentlySold
# 1    /homedetails/4433-Schenley-Farms-Ter-Pittsburg...  RecentlySold
# 2    /homedetails/519-Cato-St-Pittsburgh-PA-15213/1...  RecentlySold
# 3    /homedetails/3204-Ward-St-Pittsburgh-PA-15213/...  RecentlySold
# 4                 /b/5-bayard-rd-pittsburgh-pa-5XrWYn/           NaN
# ..                                                 ...           ...
# 455  /homedetails/3225-Parkview-Ave-Pittsburgh-PA-1...  RecentlySold
# 456  /homedetails/128-N-Craig-St-APT-407-North-Oakl...  RecentlySold
# 457  /homedetails/12-Ellsworth-Ter-Pittsburgh-PA-15...  RecentlySold
# 458  /homedetails/12-Ellsworth-Ter-Pittsburgh-PA-15...  RecentlySold
# 459  /homedetails/3334-Dawson-St-Pittsburgh-PA-1521...  RecentlySold
#
#                  sgapt  has3DModel hasVideo  isHomeRec  \
# 0    Unknown Listed By       False    False      False
# 1         RecentChange       False    False      False
# 2         RecentChange       False    False      False
# 3         RecentChange       False    False      False
# 4                  NaN       False      NaN      False
# ..                 ...         ...      ...        ...
# 455  Unknown Listed By       False    False      False
# 456  Unknown Listed By       False    False      False
# 457  Unknown Listed By       False    False      False
# 458  Unknown Listed By       False    False      False
# 459  Unknown Listed By       False    False      False
#
#                                              address        info6String  \
# 0            4305 Bigelow Blvd, Pittsburgh, PA 15213       Lauren Klein
# 1      4433 Schenley Farms Ter, Pittsburgh, PA 15213        Lisa Wagner
# 2                  519 Cato St, Pittsburgh, PA 15213    Anthony Sciulli
# 3                 3204 Ward St, Pittsburgh, PA 15213        Tina Nobers
# 4                        5 Bayard Rd, Pittsburgh, PA                NaN
# ..                                               ...                ...
# 455          3225 Parkview Ave, Pittsburgh, PA 15213                NaN
# 456  128 N Craig St APT 407, North Oakland, PA 15213      Maggie Jayson
# 457           12 Ellsworth Ter, Pittsburgh, PA 15213        Todd Mercer
# 458           12 Ellsworth Ter, Pittsburgh, PA 15213                NaN
# 459             3334 Dawson St, Pittsburgh, PA 15213  Elizabeth Kofmehl
#
#      hasAdditionalAttributions  isFeaturedListing  isShowcaseListing  \
# 0                         True              False              False
# 1                         True              False              False
# 2                         True              False              False
# 3                         True              False              False
# 4                        False              False              False
# ..                         ...                ...                ...
# 455                      False              False              False
# 456                       True              False              False
# 457                       True              False              False
# 458                      False              False              False
# 459                       True              False              False
#
#     availabilityDate  timeOnZillow  latLong.latitude  latLong.longitude  \
# 0               None  6.726636e+09         40.447483         -79.954360
# 1               None  7.653167e+09         40.451897         -79.954940
# 2               None  4.126332e+09         40.433193         -79.955530
# 3               None  3.533543e+09         40.430786         -79.955055
# 4                NaN  6.546278e+09         40.452713         -79.942530
# ..               ...           ...               ...                ...
# 455             None           NaN         40.430157         -79.953440
# 456             None  1.269576e+10         40.447884         -79.949040
# 457             None  1.269575e+10         40.449577         -79.946590
# 458             None           NaN         40.449905         -79.946910
# 459             None  1.269573e+10         40.433716         -79.953040
#
#     variableData.type variableData.text  hdpData.homeInfo.zpid  \
# 0       RECENTLY_SOLD   Sold 07/10/2023             11407883.0
# 1       RECENTLY_SOLD   Sold 07/07/2023             11407340.0
# 2       RECENTLY_SOLD   Sold 07/06/2023             11419828.0
# 3       RECENTLY_SOLD   Sold 07/03/2023             11420187.0
# 4                 NaN               NaN                    NaN
# ..                ...               ...                    ...
# 455     RECENTLY_SOLD   Sold 07/22/2020             11420319.0
# 456     RECENTLY_SOLD   Sold 07/15/2020             11528845.0
# 457     RECENTLY_SOLD   Sold 07/15/2020             11528950.0
# 458     RECENTLY_SOLD   Sold 07/15/2020            164658134.0
# 459     RECENTLY_SOLD   Sold 07/14/2020             11413689.0
#
#     hdpData.homeInfo.streetAddress hdpData.homeInfo.zipcode  \
# 0                4305 Bigelow Blvd                    15213
# 1          4433 Schenley Farms Ter                    15213
# 2                      519 Cato St                    15213
# 3                     3204 Ward St                    15213
# 4                              NaN                      NaN
# ..                             ...                      ...
# 455              3225 Parkview Ave                    15213
# 456         128 N Craig St APT 407                    15213
# 457               12 Ellsworth Ter                    15213
# 458               12 Ellsworth Ter                    15213
# 459                 3334 Dawson St                    15213
#
#     hdpData.homeInfo.city hdpData.homeInfo.state  hdpData.homeInfo.latitude  \
# 0              Pittsburgh                     PA                  40.447483
# 1              Pittsburgh                     PA                  40.451897
# 2              Pittsburgh                     PA                  40.433193
# 3              Pittsburgh                     PA                  40.430786
# 4                     NaN                    NaN                        NaN
# ..                    ...                    ...                        ...
# 455            Pittsburgh                     PA                  40.430157
# 456         North Oakland                     PA                  40.447884
# 457            Pittsburgh                     PA                  40.449577
# 458            Pittsburgh                     PA                  40.449905
# 459            Pittsburgh                     PA                  40.433716
#
#      hdpData.homeInfo.longitude  hdpData.homeInfo.price  \
# 0                    -79.954360               1000000.0
# 1                    -79.954940                675000.0
# 2                    -79.955530                290000.0
# 3                    -79.955055                170000.0
# 4                           NaN                     NaN
# ..                          ...                     ...
# 455                  -79.953440                335000.0
# 456                  -79.949040                175000.0
# 457                  -79.946590                390000.0
# 458                  -79.946910                390000.0
# 459                  -79.953040                245000.0
#
#      hdpData.homeInfo.dateSold  hdpData.homeInfo.bathrooms  \
# 0                 1.688972e+12                         4.0
# 1                 1.688713e+12                         5.0
# 2                 1.688627e+12                         2.0
# 3                 1.688368e+12                         2.0
# 4                          NaN                         NaN
# ..                         ...                         ...
# 455               1.595401e+12                         3.0
# 456               1.594796e+12                         1.0
# 457               1.594796e+12                         3.0
# 458               1.594796e+12                         2.5
# 459               1.594710e+12                         2.0
#
#      hdpData.homeInfo.bedrooms  hdpData.homeInfo.livingArea  \
# 0                          6.0                       5255.0
# 1                          4.0                       2085.0
# 2                          3.0                       1100.0
# 3                          4.0                       2152.0
# 4                          NaN                          NaN
# ..                         ...                          ...
# 455                        6.0                       1960.0
# 456                        1.0                       1090.0
# 457                        4.0                       1688.0
# 458                        3.0                          NaN
# 459                        5.0                       1968.0
#
#     hdpData.homeInfo.homeType hdpData.homeInfo.homeStatus  \
# 0               SINGLE_FAMILY               RECENTLY_SOLD
# 1               SINGLE_FAMILY               RECENTLY_SOLD
# 2               SINGLE_FAMILY               RECENTLY_SOLD
# 3               SINGLE_FAMILY               RECENTLY_SOLD
# 4                         NaN                         NaN
# ..                        ...                         ...
# 455             SINGLE_FAMILY               RECENTLY_SOLD
# 456                     CONDO               RECENTLY_SOLD
# 457                 TOWNHOUSE               RECENTLY_SOLD
# 458                 TOWNHOUSE               RECENTLY_SOLD
# 459             SINGLE_FAMILY               RECENTLY_SOLD
#
#      hdpData.homeInfo.daysOnZillow hdpData.homeInfo.isFeatured  \
# 0                             -1.0                       False
# 1                             -1.0                       False
# 2                             -1.0                       False
# 3                             -1.0                       False
# 4                              NaN                         NaN
# ..                             ...                         ...
# 455                           -1.0                       False
# 456                           -1.0                       False
# 457                           -1.0                       False
# 458                           -1.0                       False
# 459                           -1.0                       False
#
#     hdpData.homeInfo.shouldHighlight  hdpData.homeInfo.zestimate  \
# 0                              False                    985200.0
# 1                              False                    665300.0
# 2                              False                    349200.0
# 3                              False                    120600.0
# 4                                NaN                         NaN
# ..                               ...                         ...
# 455                            False                    425500.0
# 456                            False                    199600.0
# 457                            False                    479700.0
# 458                            False                    443700.0
# 459                            False                    336000.0
#
#      hdpData.homeInfo.rentZestimate hdpData.homeInfo.isUnmappable  \
# 0                            6146.0                         False
# 1                            4338.0                         False
# 2                            1900.0                         False
# 3                            2389.0                         False
# 4                               NaN                           NaN
# ..                              ...                           ...
# 455                          2749.0                         False
# 456                          1311.0                         False
# 457                          2846.0                         False
# 458                          3864.0                         False
# 459                          2700.0                         False
#
#     hdpData.homeInfo.isPreforeclosureAuction  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                        NaN
# ..                                       ...
# 455                                    False
# 456                                    False
# 457                                    False
# 458                                    False
# 459                                    False
#
#     hdpData.homeInfo.homeStatusForHDP  hdpData.homeInfo.priceForHDP  \
# 0                       RECENTLY_SOLD                     1000000.0
# 1                       RECENTLY_SOLD                      675000.0
# 2                       RECENTLY_SOLD                      290000.0
# 3                       RECENTLY_SOLD                      170000.0
# 4                                 NaN                           NaN
# ..                                ...                           ...
# 455                     RECENTLY_SOLD                      335000.0
# 456                     RECENTLY_SOLD                      175000.0
# 457                     RECENTLY_SOLD                      390000.0
# 458                     RECENTLY_SOLD                      390000.0
# 459                     RECENTLY_SOLD                      245000.0
#
#     hdpData.homeInfo.isNonOwnerOccupied hdpData.homeInfo.isPremierBuilder  \
# 0                                  True                             False
# 1                                  True                             False
# 2                                  True                             False
# 3                                  True                             False
# 4                                   NaN                               NaN
# ..                                  ...                               ...
# 455                                True                             False
# 456                                True                             False
# 457                                True                             False
# 458                                True                             False
# 459                                True                             False
#
#     hdpData.homeInfo.isZillowOwned hdpData.homeInfo.currency  \
# 0                            False                       USD
# 1                            False                       USD
# 2                            False                       USD
# 3                            False                       USD
# 4                              NaN                       NaN
# ..                             ...                       ...
# 455                          False                       USD
# 456                          False                       USD
# 457                          False                       USD
# 458                          False                       USD
# 459                          False                       USD
#
#     hdpData.homeInfo.country  hdpData.homeInfo.taxAssessedValue  \
# 0                        USA                           471000.0
# 1                        USA                           133400.0
# 2                        USA                            76800.0
# 3                        USA                           113400.0
# 4                        NaN                                NaN
# ..                       ...                                ...
# 455                      USA                           176800.0
# 456                      USA                            80700.0
# 457                      USA                           188900.0
# 458                      USA                             7200.0
# 459                      USA                           131700.0
#
#      hdpData.homeInfo.lotAreaValue hdpData.homeInfo.lotAreaUnit  \
# 0                         9448.164                         sqft
# 1                         6451.236                         sqft
# 2                         1912.284                         sqft
# 3                         4199.184                         sqft
# 4                              NaN                          NaN
# ..                             ...                          ...
# 455                       2700.000                         sqft
# 456                            NaN                          NaN
# 457                       2308.680                         sqft
# 458                       5560.000                         sqft
# 459                       2640.000                         sqft
#
#     hdpData.homeInfo.isShowcaseListing           buildingId         lotId  \
# 0                                False                  NaN           NaN
# 1                                False                  NaN           NaN
# 2                                False                  NaN           NaN
# 3                                False                  NaN           NaN
# 4                                  NaN  40.452713--79.94253  1.002196e+09
# ..                                 ...                  ...           ...
# 455                              False                  NaN           NaN
# 456                              False                  NaN           NaN
# 457                              False                  NaN           NaN
# 458                              False                  NaN           NaN
# 459                              False                  NaN           NaN
#
#      minBeds  minBaths  minArea  unitCount isBuilding  badgeInfo  \
# 0        NaN       NaN      NaN        NaN        NaN        NaN
# 1        NaN       NaN      NaN        NaN        NaN        NaN
# 2        NaN       NaN      NaN        NaN        NaN        NaN
# 3        NaN       NaN      NaN        NaN        NaN        NaN
# 4        1.0       1.0    709.0       68.0       True        NaN
# ..       ...       ...      ...        ...        ...        ...
# 455      NaN       NaN      NaN        NaN        NaN        NaN
# 456      NaN       NaN      NaN        NaN        NaN        NaN
# 457      NaN       NaN      NaN        NaN        NaN        NaN
# 458      NaN       NaN      NaN        NaN        NaN        NaN
# 459      NaN       NaN      NaN        NaN        NaN        NaN
#
#     canSaveBuilding hdpData.homeInfo.isRentalWithBasePrice lotAreaString  \
# 0               NaN                                    NaN           NaN
# 1               NaN                                    NaN           NaN
# 2               NaN                                    NaN           NaN
# 3               NaN                                    NaN           NaN
# 4             False                                    NaN           NaN
# ..              ...                                    ...           ...
# 455             NaN                                    NaN           NaN
# 456             NaN                                    NaN           NaN
# 457             NaN                                    NaN           NaN
# 458             NaN                                    NaN           NaN
# 459             NaN                                    NaN           NaN
#
#     streetViewMetadataURL streetViewURL hdpData.homeInfo.unit  \
# 0                     NaN           NaN                   NaN
# 1                     NaN           NaN                   NaN
# 2                     NaN           NaN                   NaN
# 3                     NaN           NaN                   NaN
# 4                     NaN           NaN                   NaN
# ..                    ...           ...                   ...
# 455                   NaN           NaN                   NaN
# 456                   NaN           NaN               Apt 407
# 457                   NaN           NaN                   NaN
# 458                   NaN           NaN                   NaN
# 459                   NaN           NaN                   NaN
#
#      hdpData.homeInfo.videoCount hdpData.homeInfo.listing_sub_type.is_FSBA  \
# 0                            NaN                                       NaN
# 1                            NaN                                       NaN
# 2                            NaN                                       NaN
# 3                            NaN                                       NaN
# 4                            NaN                                       NaN
# ..                           ...                                       ...
# 455                          NaN                                       NaN
# 456                          NaN                                       NaN
# 457                          NaN                                       NaN
# 458                          NaN                                       NaN
# 459                          NaN                                       NaN
#
#      hdpData.homeInfo.datePriceChanged hdpData.homeInfo.priceReduction  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ..                                 ...                             ...
# 455                                NaN                             NaN
# 456                                NaN                             NaN
# 457                                NaN                             NaN
# 458                                NaN                             NaN
# 459                                NaN                             NaN
#
#      hdpData.homeInfo.priceChange hdpData.homeInfo.contingentListingType plid
# 0                             NaN                                    NaN  NaN
# 1                             NaN                                    NaN  NaN
# 2                             NaN                                    NaN  NaN
# 3                             NaN                                    NaN  NaN
# 4                             NaN                                    NaN  NaN
# ..                            ...                                    ...  ...
# 455                           NaN                                    NaN  NaN
# 456                           NaN                                    NaN  NaN
# 457                           NaN                                    NaN  NaN
# 458                           NaN                                    NaN  NaN
# 459                           NaN                                    NaN  NaN
#
# [460 rows x 86 columns]

# %%
# df_listings = pd.json_normalize(listing_response.json()["data"]["cat1"]["searchResults"]["mapResults"]).fillna(0)
# print("Number of rows:", len(df_listings))
# print("Number of columns:", len(df_listings.columns))
# extracted_data = []

# for _, item in df_listings.iterrows():
#     address = item["hdpData.homeInfo.streetAddress"]
#     zipcode = item["hdpData.homeInfo.zipcode"]
#     city = item["hdpData.homeInfo.city"]
#     state = item["hdpData.homeInfo.state"]

#     if address != "0":
#         extracted_data.append({
#             "address": address,
#             "zipcode": zipcode,
#             "city": city,
#             "state": state
#         })

# df_extracted = pd.DataFrame(extracted_data)
# df_extracted
# Out:
# Number of rows: 460
# Number of columns: 86
#                      address zipcode           city state
# 0          4305 Bigelow Blvd   15213     Pittsburgh    PA
# 1    4433 Schenley Farms Ter   15213     Pittsburgh    PA
# 2                519 Cato St   15213     Pittsburgh    PA
# 3               3204 Ward St   15213     Pittsburgh    PA
# 4                          0       0              0     0
# ..                       ...     ...            ...   ...
# 455        3225 Parkview Ave   15213     Pittsburgh    PA
# 456   128 N Craig St APT 407   15213  North Oakland    PA
# 457         12 Ellsworth Ter   15213     Pittsburgh    PA
# 458         12 Ellsworth Ter   15213     Pittsburgh    PA
# 459           3334 Dawson St   15213     Pittsburgh    PA
#
# [460 rows x 4 columns]

# %%
df_listings = pd.json_normalize(listing_response.json()["data"]["cat1"]["searchResults"]["mapResults"])
df_listings["hdpData.homeInfo.streetAddress"].fillna(0, inplace=True)


extracted_data = []

for _, item in df_listings.iterrows():
    address = item["hdpData.homeInfo.streetAddress"]
    zipcode = item["hdpData.homeInfo.zipcode"]
    city = item["hdpData.homeInfo.city"]
    state = item["hdpData.homeInfo.state"]

    if address != 0:
        address1, address2 = split_address(address)

        extracted_data.append({
            "address1": address1,
            "address2": address2,
            "zipcode": zipcode,
            "city": city,
            "state": state
        })

df_extracted = pd.DataFrame(extracted_data)


print("Number of rows:", len(df_extracted))
print("Number of columns:", len(df_extracted.columns))
df_extracted
# Out:
# Number of rows: 420
# Number of columns: 5
#                     address1 address2 zipcode           city state
# 0          4305 Bigelow Blvd            15213     Pittsburgh    PA
# 1    4433 Schenley Farms Ter            15213     Pittsburgh    PA
# 2                519 Cato St            15213     Pittsburgh    PA
# 3               3204 Ward St            15213     Pittsburgh    PA
# 4           203 Tennyson Ave            15213     Pittsburgh    PA
# ..                       ...      ...     ...            ...   ...
# 415        3225 Parkview Ave            15213     Pittsburgh    PA
# 416           128 N Craig St  APT 407   15213  North Oakland    PA
# 417         12 Ellsworth Ter            15213     Pittsburgh    PA
# 418         12 Ellsworth Ter            15213     Pittsburgh    PA
# 419           3334 Dawson St            15213     Pittsburgh    PA
#
# [420 rows x 5 columns]

# %%
from usps import USPSApi, Address

address = Address(
    name='current resident',
    address_1='3538 Frazier St',
    city='oakland',
    state='pa',
    zipcode='15213'
)
usps = USPSApi('68048APITTS33', test=True)
validation = usps.validate_address(address)
print(validation.result)
# Out:
# {'AddressValidateResponse': {'Address': {'@ID': '0', 'Address1': '-', 'Address2': '3538 FRAZIER ST', 'City': 'OAKLAND', 'State': 'PA', 'Zip5': '15213', 'Zip4': '4402'}}}
